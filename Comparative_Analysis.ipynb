# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshi07-c/Sentiment_Analysis_Comparative_Study/blob/main/Comparative_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/output (1).csv")

# %%
display(df)
# Out:
#      Unnamed: 0                                         ReviewBody     vader  \
# 0             0  4 Hours before takeoff we received a Mail stat...  negative
# 1             1  I recently had a delay on British Airways from...  negative
# 2             2  Boarded on time, but it took ages to get to th...  positive
# 3             3  5 days before the flight, we were advised by B...  negative
# 4             4  We traveled to Lisbon for our dream vacation, ...  positive
# ..          ...                                                ...       ...
# 195         195  We have flown repeatedly with British Airways ...  negative
# 196         196  I was horrified by the extremely small seats a...  negative
# 197         197  The worst cabin experience ever: cramped seats...  negative
# 198         198  First time flying with British Airways and fir...  positive
# 199         199  The latest affront. Stood in first class line ...  negative
#
#         afinn  TextBlob      BERT       T5
# ...

# %% [markdown]
# #Positive, Negative, and Neutral Counts:

# %%
# Calculate counts for each sentiment
sentiment_counts = df[['vader', 'afinn', 'TextBlob', 'BERT', 'T5']].apply(lambda x: x.value_counts()).transpose()

# Display counts
print(sentiment_counts)
# Out:
#           negative  neutral  positive
# vader        133.0      2.0      65.0
# afinn        142.0      5.0      53.0
# TextBlob      75.0     60.0      65.0
# BERT           NaN     26.0     174.0
# T5             NaN    199.0       1.0

# %% [markdown]
# #Visualizations:

# %% [markdown]
# ##Bar Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
plt.figure(figsize=(10, 6))

# Plot the bar chart
sns.barplot(x=sentiment_counts.index, y='positive', data=sentiment_counts, color='green', label='Positive')
sns.barplot(x=sentiment_counts.index, y='negative', data=sentiment_counts, color='red', label='Negative')
sns.barplot(x=sentiment_counts.index, y='neutral', data=sentiment_counts, color='blue', label='Neutral')

# Add labels and legend
plt.xlabel('Sentiment Analysis Models')
plt.ylabel('Count')
plt.title('Sentiment Distribution Across Models')
plt.legend()

# Show the plot
plt.show()
